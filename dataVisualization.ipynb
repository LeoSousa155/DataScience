# %% [markdown]
# # Visualização de dados

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from database import Database
from dataframe_displayer import DataFrameDisplayer

# %%
# Carregar uma tabela da base de dados e mostrar o dataframe

db = Database(12)
df = db.get_dataframe_nrows(100000)
df
# Out:
# ...
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# 0           1.0  2019-12-01 00:26:58.000000  2019-12-01 00:41:45.000000
# 1           1.0  2019-12-01 00:12:08.000000  2019-12-01 00:12:14.000000
# 2           1.0  2019-12-01 00:25:53.000000  2019-12-01 00:26:04.000000
# 3           1.0  2019-12-01 00:12:03.000000  2019-12-01 00:33:19.000000
# 4           1.0  2019-12-01 00:05:27.000000  2019-12-01 00:16:32.000000
# ...         ...                         ...                         ...
# 99995       2.0  2019-12-01 14:20:06.000000  2019-12-01 15:14:15.000000
# 99996       2.0  2019-12-01 14:07:51.000000  2019-12-01 14:30:36.000000
# 99997       2.0  2019-12-01 14:07:29.000000  2019-12-01 14:33:42.000000
# 99998       2.0  2019-12-01 14:56:20.000000  2019-12-01 15:24:30.000000
# 99999       2.0  2019-12-01 14:18:31.000000  2019-12-01 14:34:38.000000
#
#        passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# ...

# %%
# visualizando dados
displayer = DataFrameDisplayer(df)
displayer.plot_column("trip_distance", "hist")
